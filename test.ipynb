# %%
import altair as alt
import geopandas as gpd
import matplotlib
import pandas as pd
import streamlit as st

# %%
alt.data_transformers.disable_max_rows()

cmpd_data = pd.read_csv('Data\Officer_Traffic_Stops.csv')

cmpd_data.head(20)
# Out:
#     OBJECTID Month_of_Stop            Reason_for_Stop            Officer_Race  \
# 0          1       2020/01  Speeding                                    White
# 1          2       2021/05  Vehicle Equipment                 Hispanic/Latino
# 2          3       2021/12  Speeding                                    White
# 3          4       2020/01  Vehicle Equipment                           White
# 4          5       2020/01  Speeding                                    White
# 5          6       2020/01  Vehicle Regulatory                Hispanic/Latino
# 6          7       2020/01  Vehicle Regulatory                          White
# 7          8       2020/01  Vehicle Regulatory                Hispanic/Latino
# 8          9       2020/01  Vehicle Regulatory                Hispanic/Latino
# 9         10       2020/01  Vehicle Regulatory                Hispanic/Latino
# 10        11       2020/01  Vehicle Regulatory                          White
# 11        12       2020/01  Vehicle Regulatory                          White
# 12        13       2020/01  Vehicle Regulatory                          White
# 13        14       2020/01  Stop Light/Sign                             White
# 14        15       2020/01  Vehicle Regulatory         Black/African American
# 15        16       2020/01  Vehicle Equipment                           White
# 16        17       2020/01  Vehicle Equipment                           White
# 17        18       2020/01  Investigation                               White
# 18        19       2020/01  Vehicle Regulatory                          White
# 19        20       2020/01  Vehicle Regulatory                          White
#
#    Officer_Gender  Officer_Years_of_Service    Driver_Race Driver_Ethnicity  \
# 0            Male                        27          White     Non-Hispanic
# 1          Female                         3          Black     Non-Hispanic
# 2            Male                        16          Black     Non-Hispanic
# 3          Female                         4          Black     Non-Hispanic
# 4            Male                        25          Black     Non-Hispanic
# 5            Male                         3          White         Hispanic
# 6            Male                         5          White         Hispanic
# 7            Male                         3          Black     Non-Hispanic
# 8            Male                         3          White     Non-Hispanic
# 9            Male                         3          Black     Non-Hispanic
# 10           Male                         3  Other/Unknown         Hispanic
# 11           Male                         8          White     Non-Hispanic
# 12           Male                        13          Black     Non-Hispanic
# 13           Male                         6  Other/Unknown         Hispanic
# 14           Male                         3          Black     Non-Hispanic
# 15           Male                         3          Black     Non-Hispanic
# 16         Female                         2          Black     Non-Hispanic
# 17           Male                         2          White         Hispanic
# 18           Male                         5          Black     Non-Hispanic
# 19           Male                         2          White     Non-Hispanic
#
#    Driver_Gender  Driver_Age Was_a_Search_Conducted   Result_of_Stop  \
# 0         Female          38                     No   Verbal Warning
# 1           Male          35                     No   Verbal Warning
# 2           Male          29                     No   Verbal Warning
# 3           Male          33                     No   Verbal Warning
# 4           Male          36                     No  Citation Issued
# 5           Male          30                     No   Verbal Warning
# 6           Male          43                     No  Citation Issued
# 7         Female          27                     No   Verbal Warning
# 8           Male          33                     No   Verbal Warning
# 9         Female          40                     No   Verbal Warning
# 10          Male          20                     No  Citation Issued
# 11          Male          32                     No  Citation Issued
# 12          Male          37                     No  Citation Issued
# 13        Female          30                     No  Citation Issued
# 14          Male          36                     No   Verbal Warning
# 15          Male          30                     No  No Action Taken
# 16        Female          30                     No   Verbal Warning
# 17          Male          22                     No   Verbal Warning
# 18        Female          40                     No  Citation Issued
# 19        Female          25                     No  Written Warning
#
#                CMPD_Division                                GlobalID
# 0   University City Division  {00000000-0000-0000-0000-000000000000}
# 1        Providence Division  {00000000-0000-0000-0000-000000000000}
# 2   University City Division  {00000000-0000-0000-0000-000000000000}
# 3   University City Division  {00000000-0000-0000-0000-000000000000}
# 4      Steele Creek Division  {00000000-0000-0000-0000-000000000000}
# 5           Eastway Division  {00000000-0000-0000-0000-000000000000}
# 6                        NaN  {00000000-0000-0000-0000-000000000000}
# 7     Hickory Grove Division  {00000000-0000-0000-0000-000000000000}
# 8          Westover Division  {00000000-0000-0000-0000-000000000000}
# 9             South Division  {00000000-0000-0000-0000-000000000000}
# 10          Central Division  {00000000-0000-0000-0000-000000000000}
# 11         Westover Division  {00000000-0000-0000-0000-000000000000}
# 12      North Tryon Division  {00000000-0000-0000-0000-000000000000}
# 13     Independence Division  {00000000-0000-0000-0000-000000000000}
# 14                       NaN  {00000000-0000-0000-0000-000000000000}
# 15      North Tryon Division  {00000000-0000-0000-0000-000000000000}
# 16         Westover Division  {00000000-0000-0000-0000-000000000000}
# 17          Central Division  {00000000-0000-0000-0000-000000000000}
# 18     Independence Division  {00000000-0000-0000-0000-000000000000}
# 19                       NaN  {00000000-0000-0000-0000-000000000000}

# %%
chart = alt.Chart(cmpd_data).mark_bar().encode(
    alt.X("Driver_Age:Q", bin=True),
    y='count()',
)
chart
# Out:
# ---------------------------------------------------------------------------
# MaxRowsError                              Traceback (most recent call last)
# File c:\Users\Joshua\Desktop\Computer\DESKTOP\Visual Analytics\Streamlit app\.venv\lib\site-packages\altair\vegalite\v5\api.py:2975, in Chart.to_dict(self, validate, format, ignore, context)
#    2971     copy.data = core.InlineData(values=[{}])  # type: ignore[assignment]
#    2972     return super(Chart, copy).to_dict(
#    2973         validate=validate, format=format, ignore=ignore, context=context
#    2974     )
# -> 2975 return super().to_dict(
#    2976     validate=validate, format=format, ignore=ignore, context=context
#    2977 )
#
# File c:\Users\Joshua\Desktop\Computer\DESKTOP\Visual Analytics\Streamlit app\.venv\lib\site-packages\altair\vegalite\v5\api.py:950, in TopLevelMixin.to_dict(self, validate, format, ignore, context)
#     948 copy = self.copy(deep=False)  # type: ignore[attr-defined]
#     949 original_data = getattr(copy, "data", Undefined)
# --> 950 copy.data = _prepare_data(original_data, context)
#     952 if original_data is not Undefined:
#     953     context["data"] = original_data
#
# File c:\Users\Joshua\Desktop\Computer\DESKTOP\Visual Analytics\Streamlit app\.venv\lib\site-packages\altair\vegalite\v5\api.py:111, in _prepare_data(data, context)
#     109 # convert dataframes  or objects with __geo_interface__ to dict
#     110 elif isinstance(data, pd.DataFrame) or hasattr(data, "__geo_interface__"):
# --> 111     data = _pipe(data, data_transformers.get())
#     113 # convert string input to a URLData
#     114 elif isinstance(data, str):
#
# File c:\Users\Joshua\Desktop\Computer\DESKTOP\Visual Analytics\Streamlit app\.venv\lib\site-packages\toolz\functoolz.py:628, in pipe(data, *funcs)
#     608 """ Pipe a value through a sequence of functions
#     609
#     610 I.e. ``pipe(data, f, g, h)`` is equivalent to ``h(g(f(data)))``
#    (...)
#     625     thread_last
#     626 """
#     627 for func in funcs:
# --> 628     data = func(data)
#     629 return data
#
# File c:\Users\Joshua\Desktop\Computer\DESKTOP\Visual Analytics\Streamlit app\.venv\lib\site-packages\toolz\functoolz.py:304, in curry.__call__(self, *args, **kwargs)
#     302 def __call__(self, *args, **kwargs):
#     303     try:
# --> 304         return self._partial(*args, **kwargs)
#     305     except TypeError as exc:
#     306         if self._should_curry(args, kwargs, exc):
#
# File c:\Users\Joshua\Desktop\Computer\DESKTOP\Visual Analytics\Streamlit app\.venv\lib\site-packages\altair\vegalite\data.py:23, in default_data_transformer(data, max_rows)
#      19 @curried.curry
#      20 def default_data_transformer(
#      21     data: DataType, max_rows: int = 5000
#      22 ) -> ToValuesReturnType:
# ---> 23     return curried.pipe(data, limit_rows(max_rows=max_rows), to_values)
#
# File c:\Users\Joshua\Desktop\Computer\DESKTOP\Visual Analytics\Streamlit app\.venv\lib\site-packages\toolz\functoolz.py:628, in pipe(data, *funcs)
#     608 """ Pipe a value through a sequence of functions
#     609
#     610 I.e. ``pipe(data, f, g, h)`` is equivalent to ``h(g(f(data)))``
#    (...)
#     625     thread_last
#     626 """
#     627 for func in funcs:
# --> 628     data = func(data)
#     629 return data
#
# File c:\Users\Joshua\Desktop\Computer\DESKTOP\Visual Analytics\Streamlit app\.venv\lib\site-packages\toolz\functoolz.py:304, in curry.__call__(self, *args, **kwargs)
#     302 def __call__(self, *args, **kwargs):
#     303     try:
# --> 304         return self._partial(*args, **kwargs)
#     305     except TypeError as exc:
#     306         if self._should_curry(args, kwargs, exc):
#
# File c:\Users\Joshua\Desktop\Computer\DESKTOP\Visual Analytics\Streamlit app\.venv\lib\site-packages\altair\utils\data.py:118, in limit_rows(data, max_rows)
#     115     return pa_table
#     117 if max_rows is not None and len(values) > max_rows:
# --> 118     raise_max_rows_error()
#     120 return data
#
# File c:\Users\Joshua\Desktop\Computer\DESKTOP\Visual Analytics\Streamlit app\.venv\lib\site-packages\altair\utils\data.py:81, in limit_rows.<locals>.raise_max_rows_error()
#      80 def raise_max_rows_error():
# ---> 81     raise MaxRowsError(
#      82         "The number of rows in your dataset is greater "
#      83         f"than the maximum allowed ({max_rows}).\n\n"
#      84         "Try enabling the VegaFusion data transformer which "
#      85         "raises this limit by pre-evaluating data\n"
#      86         "transformations in Python.\n"
#      87         "    >> import altair as alt\n"
#      88         '    >> alt.data_transformers.enable("vegafusion")\n\n'
#      89         "Or, see https://altair-viz.github.io/user_guide/large_datasets.html "
#      90         "for additional information\n"
#      91         "on how to plot large datasets."
#      92     )
#
# MaxRowsError: The number of rows in your dataset is greater than the maximum allowed (5000).
#
# Try enabling the VegaFusion data transformer which raises this limit by pre-evaluating data
# transformations in Python.
#     >> import altair as alt
#     >> alt.data_transformers.enable("vegafusion")
#
# Or, see https://altair-viz.github.io/user_guide/large_datasets.html for additional information
# on how to plot large datasets.
# alt.Chart(...)
